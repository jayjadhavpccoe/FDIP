# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage import img_as_uint
from skimage.io import imshow, imread
from skimage.color import rgb2hsv
from skimage.color import rgb2gray

image = cv2.imread(r"C:\Users\ML\Desktop\elephant.jpg")
plt.title("Original Image")

imshow(image)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.title("Grayscale Image")

imshow(gray)

# %%
plt.hist(gray.ravel(), bins=256, range=[0,256])
plt.title("Histogram of Grayscale Image")
plt.show()

# %%
import random
import cv2


salt_and_paper = cv2.imread(r'C:\Users\ML\Desktop\elephant.jpg', cv2.IMREAD_GRAYSCALE)

row , col = salt_and_paper.shape

number_of_pixels = random.randint(10000, 100000)
for i in range(number_of_pixels):
    y_coord=random.randint(0, row - 1)
    x_coord=random.randint(0, col - 1)
    salt_and_paper[y_coord][x_coord] = 255

number_of_pixels = random.randint(10000 , 100000)
for i in range(number_of_pixels):
    y_coord=random.randint(0, row - 1)
    x_coord=random.randint(0, col - 1)
    salt_and_paper[y_coord][x_coord] = 0
plt.title("Salt and Paper Noise")
imshow(salt_and_paper)

# %%
plt.hist(salt_and_paper.ravel(), bins=256, range=[0,256])
plt.title("Histogram of Salt and Paper Noise Image")
plt.show()

# %%
import cv2

img = cv2.imread(r'C:\Users\ML\Desktop\elephant.jpg', cv2.IMREAD_GRAYSCALE)

mean = 0
std_dev = 35
gaussian_noise = np.random.normal(loc=mean, scale=std_dev, size=img.shape).astype(np.float32)

noisy_img = img.astype(np.float32) + gaussian_noise

noisy_img = np.clip(noisy_img, 0, 255).astype(np.uint8)

plt.title("Guassian Noise")
imshow(noisy_img)

# %%
plt.hist(guassian.ravel(), bins=256, range=[0,256])
plt.title("Histogram of Guassian Noise Image")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 plt.hist(guassian.ravel(), bins=256, range=[0,256])
#       2 plt.title("Histogram of Guassian Noise Image")
#       3 plt.show()
#
# NameError: name 'guassian' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt

def generate_speckle_noise(image_shape, mean=0, variance=1):
    noise = np.random.normal(mean, variance, size=image_shape)
    speckle_noise = noise * np.ones(image_shape)
    return speckle_noise

img = cv2.imread(r'C:\Users\ML\Desktop\elephant.jpg', cv2.IMREAD_GRAYSCALE)
image_shape = img.shape # Specify the dimensions of the image

# Add speckle noise to the image
speckle_variance = 1  # Adjust the variance to control the intensity of the noise
speckle_noise = generate_speckle_noise(image_shape, variance=speckle_variance)
noisy_image = img + speckle_noise

# Display the noisy image
plt.imshow(noisy_image, cmap='gray')
plt.title('Image with Speckle Noise')
plt.show()

# %%
plt.hist(noisy_image.ravel(), bins=256, range=[0,256])
plt.title("Histogram of Speckle Noise Image")
plt.show()
